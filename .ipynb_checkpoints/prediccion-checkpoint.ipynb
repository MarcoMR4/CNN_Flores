# %%
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt


#Nombres de clases o subcarpetas del dataset 
flores = ["Flor1_OrquideaRosa", "Flor2_RosalRojo", "Flor3_MargaritaNaranja", "flor4_PequeniaAzul", "Flor5_OjoCanario"]

# Cargar el modelo entrenado
flower_model = load_model("trained/flores1.h5")

# Imagen de prueba 
new_image_path = "prueba/eja1.jpg"
new_image = plt.imread(new_image_path)
new_image = np.array(new_image)

new_image = new_image.reshape(1, 26, 26, 3)

new_image = new_image / 255.0 

predictions = flower_model.predict(new_image)

predicted_class = np.argmax(predictions)

print("La imagen se clasifica como:", flores[predicted_class])

imshow
print("Probabilidades:", predictions)
# Out:
# WARNING:tensorflow:From C:\Users\Mark\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Mark\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Mark\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# 1/1 [==============================] - 0s 300ms/step
# La imagen se clasifica como: Flor3_MargaritaNaranja
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 27
#      23 predicted_class = np.argmax(predictions)
#      25 print("La imagen se clasifica como:", flores[predicted_class])
# ---> 27 imshow
#      28 print("Probabilidades:", predictions)
#
# NameError: name 'imshow' is not defined

# %%
# Prueba con video 


import cv2

# Definición de la lista de nombres de clases (reemplaza esto con tus propias clases)
flores = ["Flor1_OrquideaRosa", "Flor2_RosalRojo", "Flor3_MargaritaNaranja", "flor4_PequeniaAzul", "Flor5_OjoCanario"]


# Cargar el modelo entrenado
flower_model = load_model("trained/flores1.h5")

# Ruta al archivo de video (reemplaza esto con la ruta de tu video)
video_path = "pruebaVideo/V1.mp4"

# Inicializar el objeto de captura de video
cap = cv2.VideoCapture(video_path)

while True:
    # Lee un fotograma del video
    ret, frame = cap.read()

    # Verifica si se ha llegado al final del video
    if not ret:
        break

    # Realiza las mismas operaciones que para una imagen individual
    # Asegúrate de que el tamaño del fotograma coincida con el tamaño de entrada del modelo
    frame = cv2.resize(frame, (26, 26))

    # Asegúrate de que el fotograma tiene las mismas dimensiones que las imágenes con las que entrenaste tu modelo
    frame = frame.reshape(1, 26, 26, 3)

    # Normaliza el fotograma si es necesario
    frame = frame / 255.0  # Normalizar entre 0 y 1, si tus imágenes originales también se normalizaron

    # Realiza la predicción
    predictions = flower_model.predict(frame)

    # Obtén la clase predicha (la clase con la probabilidad más alta)
    predicted_class = np.argmax(predictions)

    # Imprime la clase predicha
    print("El fotograma se clasifica como:", flores[predicted_class])

    # Muestra el fotograma con la clase predicha
    # cv2.imshow("Video", frame)

    # Espera 1 milisegundo y verifica si se presiona la tecla 'q' para salir del bucle
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Libera los recursos
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 74ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 11ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 21ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 19ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 14ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 36ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 19ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 10ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 13ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 40ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 21ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 10ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 21ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 36ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 38ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 11ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 20ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 10ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 38ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 12ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 36ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 43ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 40ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 38ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 44ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 11ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 36ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 29ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 91ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 20ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 19ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 12ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 12ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 38ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 36ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 26ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 21ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 16ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 10ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 24ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 42ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 27ms/step
# El fotograma se clasifica como: Flor2_RosalRojo
# 1/1 [==============================] - 0s 20ms/step
# El fotograma se clasifica como: Flor1_OrquideaRosa
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: Flor2_RosalRojo
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: Flor2_RosalRojo
# 1/1 [==============================] - 0s 14ms/step
# El fotograma se clasifica como: Flor2_RosalRojo
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: Flor2_RosalRojo
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 31ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 32ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 30ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 28ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 34ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 40ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 18ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 21ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 37ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 17ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 33ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 39ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 23ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 22ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 12ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 25ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 35ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul
# 1/1 [==============================] - 0s 37ms/step
# El fotograma se clasifica como: flor4_PequeniaAzul

# %%
from tensorflow.keras.models import load_model
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Nombres de clases o subcarpetas del dataset
flores = ["Flor1_OrquideaRosa", "Flor2_RosalRojo", "Flor3_MargaritaNaranja", "flor4_RaizPlomoAzul", "Flor5_OjoCanario"]

# Cargar el modelo entrenado
flower_model = load_model("trained/flores1.h5")

# Ruta de la imagen de prueba
ruta_prueba = "prueba/rose9.webp"
new_image_path = ruta_prueba
copy_image_path = ruta_prueba

# Cargar la imagen original
img = image.load_img(new_image_path, target_size=(26, 26))
img_array_original = image.img_to_array(img)
img_array_original /= 255.0

# imagen original 
img_copy = image.load_img(copy_image_path)

# Agregar el batch dimension (1, 26, 26, 3) para la predicción
img_array_resized_batch = np.expand_dims(img_array_original, axis=0)

# Realizar la predicción con la imagen redimensionada
predictions = flower_model.predict(img_array_resized_batch)
predicted_class = np.argmax(predictions)

# Mostrar la imagen original con la etiqueta predicha
plt.subplot(1, 2, 1)
plt.imshow(img_copy)
probHighest = round(np.max(predictions)*100)
plt.title(f"Clase Predicha: {flores[predicted_class]} \n\n Probabilidad: {probHighest}%")


 #Mostrar la imagen redimensionada
plt.subplot(1, 2, 2)
plt.imshow(img_array_original)
plt.title("Imagen Redimensionada")
plt.show()

print("Probabilidades:", predictions)
# Out:
# 1/1 [==============================] - 0s 157ms/step
# Probabilidades: [[0.00447311 0.8110121  0.12604623 0.00109105 0.05737757]]
